# %%
#2018-08-07 13:13:04.742507
# %load_ext metapack.jupyter.magic

# %%
CACHE_DIR='/Users/eric/Library/Application Support/metapack/'
RESOURCE_NAME='stations'
RESOLVED_URL='file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/notebooks/Add_Features.ipynb#stations'
WORKING_DIR='/Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch'
METATAB_DOC='metapack+file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/metadata.csv'
METATAB_WORKING_DIR='/Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch'
METATAB_PACKAGE='metapack+file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/'
name='stations'
description='Measurement stations'
url='notebooks/Add_Features.ipynb#stations'

# %%
METAPACK_BUILDING=True

# %%
import matplotlib.pyplot as plt 
import metapack as mp
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

from metapack.appurl import SearchUrl 
SearchUrl.initialize()

# %%
pkg = mp.jupyter.open_package()
pkg
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/jupyter/ipython.py in open_package(locals, dr)
#      54         # Running in a package build
# ---> 55         return op(locals['metatab_doc'])
#      56
#
# KeyError: 'metatab_doc'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/proj/virt-proj/metapack/metapack-dev/rowgenerators/rowgenerators/core.py in get_generator(source, **kwargs)
#      80     try:
# ---> 81         return classes[0](ref, **kwargs)
#      82     except NotImplementedError:
#
# ~/proj/virt-proj/metapack/metapack-dev/rowgenerators/rowgenerators/generator/csv.py in __init__(self, ref, cache, working_dir, env, **kwargs)
#      21         if not self.url.exists():
# ---> 22             raise FileNotFoundError(self.url)
#      23
#
# FileNotFoundError: file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/_packages/sandiegodata.org-beachwatch-1/metadata.csv
#
# The above exception was the direct cause of the following exception:
#
# RowGeneratorError                         Traceback (most recent call last)
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/doc.py in __init__(self, ref, decl, cache, resolver, package_url, clean_cache, downloader)
#      67         try:
# ---> 68             super().__init__(ref, decl, package_url, cache, resolver, clean_cache)
#      69         except RowGeneratorError as e:
#
# ~/proj/virt-proj/metapack/metapack-dev/metatab/metatab/doc.py in __init__(self, ref, decl, package_url, cache, resolver, clean_cache)
#      77             try:
# ---> 78                 self.load_terms(self._term_parser)
#      79             except SourceError as e:
#
# ~/proj/virt-proj/metapack/metapack-dev/metatab/metatab/doc.py in load_terms(self, terms)
#     469
# --> 470         for t in terms:
#     471
#
# ~/proj/virt-proj/metapack/metapack-dev/metatab/metatab/parser.py in __iter__(self)
#     430
# --> 431             for i, t in enumerate(self.generate_terms(target, self.root)):
#     432
#
# ~/proj/virt-proj/metapack/metapack-dev/metatab/metatab/parser.py in generate_terms(self, ref, root, file_type)
#     318         else:
# --> 319             row_gen = get_generator(ref)
#     320             ref_path = ref.path
#
# ~/proj/virt-proj/metapack/metapack-dev/rowgenerators/rowgenerators/core.py in get_generator(source, **kwargs)
#      84     except Exception as e:
# ---> 85         raise RowGeneratorError("Failed to instantiate generator for class '{}', ref '{}'".format(classes[0], ref)) from e
#      86
#
# RowGeneratorError: Failed to instantiate generator for class '<class 'rowgenerators.generator.csv.CsvSource'>', ref 'file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/_packages/sandiegodata.org-beachwatch-1/metadata.csv'
#
# During handling of the above exception, another exception occurred:
#
# MetatabFileNotFound                       Traceback (most recent call last)
# <ipython-input-5-610ee5fce481> in <module>()
# ----> 1 pkg = mp.jupyter.open_package()
#       2 pkg
#
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/jupyter/ipython.py in open_package(locals, dr)
#      87             built_package = join(build_package_dir, package_name)
#      88             try:
# ---> 89                 return op(built_package)
#      90             except RowGeneratorError as e:
#      91                 pass  # Probably could not open the metadata file.
#
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/package/core.py in open_package(ref, downloader)
#     650         u = MetapackUrl(ref, downloader=downloader)
#     651
# --> 652         resource = u.resource
#     653
#     654     p = MetapackDoc(u, downloader=downloader)
#
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/appurl.py in resource(self)
#     184         """Return the Metapack resource, different from the URL resource returned by get_resource"""
#     185
# --> 186         r = self.doc.resource(self.fragment[0])
#     187         return r
#     188
#
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/appurl.py in doc(self)
#     113         from metapack import MetapackDoc
#     114         t = self.get_resource().get_target()
# --> 115         return MetapackDoc(t, package_url=self.package_url)
#     116
#     117     @property
#
# ~/proj/virt-proj/metapack/metapack-dev/metapack/metapack/doc.py in __init__(self, ref, decl, cache, resolver, package_url, clean_cache, downloader)
#      68             super().__init__(ref, decl, package_url, cache, resolver, clean_cache)
#      69         except RowGeneratorError as e:
# ---> 70             raise MetatabFileNotFound("Failed to get Metatabfile for reference: '{}' ".format(ref))
#      71
#      72         self.default_resource = None  # Set externally in open_package when the URL has a resource.
#
# MetatabFileNotFound: Failed to get Metatabfile for reference: 'metapack+file:///Users/eric/proj/virt-proj/water/water-datasets/derived/sandiegodata.org-beachwatch/_packages/sandiegodata.org-beachwatch-1/metadata.csv'

# %%
beachwatch_source = pkg.reference('beachwatch_source').read_csv()
# It looks like the prefix of the station code groups stations, maybe into watersheds.

# %%
measurement_cols = [
 'sampledate',
 'collectiontime',
 'stationcode',
 'stationgroup',
 'result',
 'methodname',
 'analyte',
 'unit',
 'labbatch',                
 'resultqualcode',
 'qacode',
 'sampleagency',
 'labagency',
 'submittingagency'
]

station_cols = [
 'stationname',
 'stationcode',
 'stationgroup',
 'targetlatitude',
 'targetlongitude',
]

beachwatch_source['stationgroup'] = beachwatch_source.stationcode.str[:2]

obs = beachwatch_source[measurement_cols]
stations = beachwatch_source[station_cols].drop_duplicates()

# %%
len(obs), len(stations)
# Out:
# (202257, 172)

# %% [markdown]
# # Group Statistics and Measure Codes

# %%
# Create a dataset of all of the unique measure codes, then give them unique values
_1 = obs[['analyte','methodname','unit']].drop_duplicates()
_1['measure_code'] = 0
_1 = _1.set_index(list(_1.columns)[:-1]).sort_index()
_1['measure_code'] = _1.reset_index().index # Reset_index() renumbers the index
measure_codes = _1
measure_codes.head()
# Out:
#                                        measure_code
# analyte         methodname unit
# Coliform, Fecal MTF        MPN/100 mL             0
#                            cfu/100mL              1
#                 SM 9221 E  MPN/100 mL             2
#                            cfu/100mL              3
#                 SM 9222 B  MPN/100 mL             4

# %%
obs_1 = obs.reset_index().set_index(['analyte','methodname','unit']).join(measure_codes).reset_index()
obs_1.head()
# Out:
#            analyte methodname        unit  index sampledate collectiontime  \
# 0  Coliform, Fecal        MTF  MPN/100 mL      4 1999-05-26     2018-08-07
# 1  Coliform, Fecal        MTF  MPN/100 mL     11 1999-10-13     2018-08-07
# 2  Coliform, Fecal        MTF  MPN/100 mL     14 1999-10-26     2018-08-07
# 3  Coliform, Fecal        MTF  MPN/100 mL     19 2000-03-21     2018-08-07
# 4  Coliform, Fecal        MTF  MPN/100 mL     25 2000-05-24     2018-08-07
#
#   stationcode stationgroup  result       labbatch resultqualcode qacode  \
# 0      EH-010           EH    20.0   SH-5/26/1999              <     NR
# 1      EH-010           EH     0.0  SH-10/13/1999              =     NR
# 2      EH-010           EH    20.0  SH-10/26/1999              <     NR
# 3      EH-010           EH    20.0   SH-3/21/2000              <     NR
# 4      EH-010           EH   230.0   SH-5/24/2000              =     NR
#
#   sampleagency labagency submittingagency  measure_code
# 0       SDCDEH    SDCDEH           SDCDEH             0
# 1       SDCDEH    SDCDEH           SDCDEH             0
# 2       SDCDEH    SDCDEH           SDCDEH             0
# 3       SDCDEH    SDCDEH           SDCDEH             0
# 4       SDCDEH    SDCDEH           SDCDEH             0

# %%
# Compute stats for each group of
obs_1['lresult'] = obs_1.result.apply(lambda x: np.nan if x == 0 else np.log(x))

_g = obs_1[['stationcode','measure_code','sampledate', 'result', 'lresult']].groupby(['stationcode','measure_code'])
_1 = _g.agg({'result':['count','std','mean'], 
             'lresult':['std','mean']})
    
# _1 now has multi-level column names, so we need to compress them. 
_1.columns = [ '_'.join(e).replace('result_','result_group_') for e in _1.columns.get_values()]

# compute quantiles 
_2 = obs_1[['stationcode','measure_code', 'result', 'lresult']]\
        .groupby(['stationcode','measure_code'])\
        .quantile([.25,.5, .75])
        
_2.index.names = ['stationcode', 'measure_code', 'quantile']
_2 = _2.unstack(-1)

_2.columns = [ '_'.join( str(ee) for ee in e).replace('0.','') for e in _2.columns.get_values()]

_2.rename(columns={
    'lresult_25': 'lresult_group_25pctl',
    'lresult_5':  'lresult_group_median',
    'lresult_75': 'lresult_group_75pctl',
    'result_25':  'result_group_25pctl',
    'result_5':   'result_group_median',
    'result_75':  'result_group_75pctl',
}, inplace=True)

# Finally, join
obs_m = obs_1.reset_index().set_index(['stationcode','measure_code']).join(_1).join(_2).reset_index().copy()
obs_m.head()
# Out:
#   stationcode  measure_code  level_0          analyte methodname        unit  \
# 0      EH-010             0        0  Coliform, Fecal        MTF  MPN/100 mL
# 1      EH-010             0        1  Coliform, Fecal        MTF  MPN/100 mL
# 2      EH-010             0        2  Coliform, Fecal        MTF  MPN/100 mL
# 3      EH-010             0        3  Coliform, Fecal        MTF  MPN/100 mL
# 4      EH-010             0        4  Coliform, Fecal        MTF  MPN/100 mL
#
#    index sampledate collectiontime stationgroup         ...           \
# 0      4 1999-05-26     2018-08-07           EH         ...
# 1     11 1999-10-13     2018-08-07           EH         ...
# 2     14 1999-10-26     2018-08-07           EH         ...
# 3     19 2000-03-21     2018-08-07           EH         ...
# 4     25 2000-05-24     2018-08-07           EH         ...
#
#    result_group_std result_group_mean lresult_group_std lresult_group_mean  \
# 0       1647.469843        376.478873          1.439884           3.633361
# 1       1647.469843        376.478873          1.439884           3.633361
# 2       1647.469843        376.478873          1.439884           3.633361
# 3       1647.469843        376.478873          1.439884           3.633361
# 4       1647.469843        376.478873          1.439884           3.633361
#
#   lresult_group_25pctl lresult_group_median lresult_group_75pctl  \
# 0             2.995732             2.995732             2.995732
# 1             2.995732             2.995732             2.995732
# 2             2.995732             2.995732             2.995732
# 3             2.995732             2.995732             2.995732
# 4             2.995732             2.995732             2.995732
#
#    result_group_25pctl  result_group_median  result_group_75pctl
# 0                 20.0                 20.0                 20.0
# 1                 20.0                 20.0                 20.0
# 2                 20.0                 20.0                 20.0
# 3                 20.0                 20.0                 20.0
# 4                 20.0                 20.0                 20.0
#
# [5 rows x 29 columns]

# %%
#list(obs_m.columns)

# %% [markdown]
# # Adding Features

# %%
obs_m['result_gt_median'] = (obs_m.result > obs_m.result_group_median).astype(int)
obs_m['result_gt_mean']   = (obs_m.result > obs_m.result_group_mean).astype(int)
obs_m['result_lte_25pctl']   = (obs_m.result <= obs_m.result_group_25pctl).astype(int)
obs_m['result_gte_75pctl']   = (obs_m.result >= obs_m.result_group_75pctl).astype(int)

obs_m['lresult_gt_lmedian'] = (obs_m.lresult > obs_m.lresult_group_median).astype(int)
obs_m['lresult_gt_lmean']   = (obs_m.lresult > obs_m.lresult_group_mean).astype(int)
obs_m['lresult_lte_25pctl']   = (obs_m.lresult <= obs_m.lresult_group_25pctl).astype(int)
obs_m['lresult_gte_75pctl']   = (obs_m.lresult >= obs_m.lresult_group_75pctl).astype(int)

# %%
obs_m.head().T
# Out:
#                                         0                    1  \
# stationcode                        EH-010               EH-010
# measure_code                            0                    0
# level_0                                 0                    1
# analyte                   Coliform, Fecal      Coliform, Fecal
# methodname                            MTF                  MTF
# unit                           MPN/100 mL           MPN/100 mL
# index                                   4                   11
# sampledate            1999-05-26 00:00:00  1999-10-13 00:00:00
# collectiontime        2018-08-07 00:00:00  2018-08-07 00:00:00
# stationgroup                           EH                   EH
# result                                 20                    0
# labbatch                     SH-5/26/1999        SH-10/13/1999
# resultqualcode                          <                    =
# qacode                                 NR                   NR
# sampleagency                       SDCDEH               SDCDEH
# labagency                          SDCDEH               SDCDEH
# submittingagency                   SDCDEH               SDCDEH
# lresult                           2.99573                  NaN
# result_group_count                    213                  213
# result_group_std                  1647.47              1647.47
# result_group_mean                 376.479              376.479
# lresult_group_std                 1.43988              1.43988
# lresult_group_mean                3.63336              3.63336
# lresult_group_25pctl              2.99573              2.99573
# lresult_group_median              2.99573              2.99573
# lresult_group_75pctl              2.99573              2.99573
# result_group_25pctl                    20                   20
# result_group_median                    20                   20
# result_group_75pctl                    20                   20
# result_gt_median                        0                    0
# result_gt_mean                          0                    0
# result_lte_25pctl                       1                    1
# result_gte_75pctl                       1                    0
# lresult_gt_lmedian                      0                    0
# lresult_gt_lmean                        0                    0
# lresult_lte_25pctl                      1                    0
# lresult_gte_75pctl                      1                    0
#
#                                         2                    3  \
# stationcode                        EH-010               EH-010
# measure_code                            0                    0
# level_0                                 2                    3
# analyte                   Coliform, Fecal      Coliform, Fecal
# methodname                            MTF                  MTF
# unit                           MPN/100 mL           MPN/100 mL
# index                                  14                   19
# sampledate            1999-10-26 00:00:00  2000-03-21 00:00:00
# collectiontime        2018-08-07 00:00:00  2018-08-07 00:00:00
# stationgroup                           EH                   EH
# result                                 20                   20
# labbatch                    SH-10/26/1999         SH-3/21/2000
# resultqualcode                          <                    <
# qacode                                 NR                   NR
# sampleagency                       SDCDEH               SDCDEH
# labagency                          SDCDEH               SDCDEH
# submittingagency                   SDCDEH               SDCDEH
# lresult                           2.99573              2.99573
# result_group_count                    213                  213
# result_group_std                  1647.47              1647.47
# result_group_mean                 376.479              376.479
# lresult_group_std                 1.43988              1.43988
# lresult_group_mean                3.63336              3.63336
# lresult_group_25pctl              2.99573              2.99573
# lresult_group_median              2.99573              2.99573
# lresult_group_75pctl              2.99573              2.99573
# result_group_25pctl                    20                   20
# result_group_median                    20                   20
# result_group_75pctl                    20                   20
# result_gt_median                        0                    0
# result_gt_mean                          0                    0
# result_lte_25pctl                       1                    1
# result_gte_75pctl                       1                    1
# lresult_gt_lmedian                      0                    0
# lresult_gt_lmean                        0                    0
# lresult_lte_25pctl                      1                    1
# lresult_gte_75pctl                      1                    1
#
#                                         4
# stationcode                        EH-010
# measure_code                            0
# level_0                                 4
# analyte                   Coliform, Fecal
# methodname                            MTF
# unit                           MPN/100 mL
# index                                  25
# sampledate            2000-05-24 00:00:00
# collectiontime        2018-08-07 00:00:00
# stationgroup                           EH
# result                                230
# labbatch                     SH-5/24/2000
# resultqualcode                          =
# qacode                                 NR
# sampleagency                       SDCDEH
# labagency                          SDCDEH
# submittingagency                   SDCDEH
# lresult                           5.43808
# result_group_count                    213
# result_group_std                  1647.47
# result_group_mean                 376.479
# lresult_group_std                 1.43988
# lresult_group_mean                3.63336
# lresult_group_25pctl              2.99573
# lresult_group_median              2.99573
# lresult_group_75pctl              2.99573
# result_group_25pctl                    20
# result_group_median                    20
# result_group_75pctl                    20
# result_gt_median                        1
# result_gt_mean                          0
# result_lte_25pctl                       0
# result_gte_75pctl                       1
# lresult_gt_lmedian                      1
# lresult_gt_lmean                        1
# lresult_lte_25pctl                      0
# lresult_gte_75pctl                      1

# %%
 list(obs_m.columns)
  
obs_m_cols =[
    'stationcode',
    'stationgroup',
    'sampledate',
    'collectiontime',
    'measure_code',
    'analyte',
    'methodname',
    'unit',
    'result',
    'result_group_count',
    'result_group_std',
    'result_group_mean',
    'result_group_25pctl',
    'result_group_median',
    'result_group_75pctl',
    'result_gt_median',
    'result_gt_mean',
    'result_lte_25pctl',
    'result_gte_75pctl',
    'lresult',
    'lresult_group_std',
    'lresult_group_mean',
    'lresult_group_25pctl',
    'lresult_group_median',
    'lresult_group_75pctl',
    'lresult_gt_lmedian',
    'lresult_gt_lmean',
    'lresult_lte_25pctl',
    'lresult_gte_75pctl',
    'labbatch',
    'resultqualcode',
    'qacode',
    'sampleagency',
    'labagency',
    'submittingagency'
]

obs_m = obs_m[obs_m_cols]
obs_m.head().T
# Out:
#                                         0                    1  \
# stationcode                        EH-010               EH-010
# stationgroup                           EH                   EH
# sampledate            1999-05-26 00:00:00  1999-10-13 00:00:00
# collectiontime        2018-08-07 00:00:00  2018-08-07 00:00:00
# measure_code                            0                    0
# analyte                   Coliform, Fecal      Coliform, Fecal
# methodname                            MTF                  MTF
# unit                           MPN/100 mL           MPN/100 mL
# result                                 20                    0
# result_group_count                    213                  213
# result_group_std                  1647.47              1647.47
# result_group_mean                 376.479              376.479
# result_group_25pctl                    20                   20
# result_group_median                    20                   20
# result_group_75pctl                    20                   20
# result_gt_median                        0                    0
# result_gt_mean                          0                    0
# result_lte_25pctl                       1                    1
# result_gte_75pctl                       1                    0
# lresult                           2.99573                  NaN
# lresult_group_std                 1.43988              1.43988
# lresult_group_mean                3.63336              3.63336
# lresult_group_25pctl              2.99573              2.99573
# lresult_group_median              2.99573              2.99573
# lresult_group_75pctl              2.99573              2.99573
# lresult_gt_lmedian                      0                    0
# lresult_gt_lmean                        0                    0
# lresult_lte_25pctl                      1                    0
# lresult_gte_75pctl                      1                    0
# labbatch                     SH-5/26/1999        SH-10/13/1999
# resultqualcode                          <                    =
# qacode                                 NR                   NR
# sampleagency                       SDCDEH               SDCDEH
# labagency                          SDCDEH               SDCDEH
# submittingagency                   SDCDEH               SDCDEH
#
#                                         2                    3  \
# stationcode                        EH-010               EH-010
# stationgroup                           EH                   EH
# sampledate            1999-10-26 00:00:00  2000-03-21 00:00:00
# collectiontime        2018-08-07 00:00:00  2018-08-07 00:00:00
# measure_code                            0                    0
# analyte                   Coliform, Fecal      Coliform, Fecal
# methodname                            MTF                  MTF
# unit                           MPN/100 mL           MPN/100 mL
# result                                 20                   20
# result_group_count                    213                  213
# result_group_std                  1647.47              1647.47
# result_group_mean                 376.479              376.479
# result_group_25pctl                    20                   20
# result_group_median                    20                   20
# result_group_75pctl                    20                   20
# result_gt_median                        0                    0
# result_gt_mean                          0                    0
# result_lte_25pctl                       1                    1
# result_gte_75pctl                       1                    1
# lresult                           2.99573              2.99573
# lresult_group_std                 1.43988              1.43988
# lresult_group_mean                3.63336              3.63336
# lresult_group_25pctl              2.99573              2.99573
# lresult_group_median              2.99573              2.99573
# lresult_group_75pctl              2.99573              2.99573
# lresult_gt_lmedian                      0                    0
# lresult_gt_lmean                        0                    0
# lresult_lte_25pctl                      1                    1
# lresult_gte_75pctl                      1                    1
# labbatch                    SH-10/26/1999         SH-3/21/2000
# resultqualcode                          <                    <
# qacode                                 NR                   NR
# sampleagency                       SDCDEH               SDCDEH
# labagency                          SDCDEH               SDCDEH
# submittingagency                   SDCDEH               SDCDEH
#
#                                         4
# stationcode                        EH-010
# stationgroup                           EH
# sampledate            2000-05-24 00:00:00
# collectiontime        2018-08-07 00:00:00
# measure_code                            0
# analyte                   Coliform, Fecal
# methodname                            MTF
# unit                           MPN/100 mL
# result                                230
# result_group_count                    213
# result_group_std                  1647.47
# result_group_mean                 376.479
# result_group_25pctl                    20
# result_group_median                    20
# result_group_75pctl                    20
# result_gt_median                        1
# result_gt_mean                          0
# result_lte_25pctl                       0
# result_gte_75pctl                       1
# lresult                           5.43808
# lresult_group_std                 1.43988
# lresult_group_mean                3.63336
# lresult_group_25pctl              2.99573
# lresult_group_median              2.99573
# lresult_group_75pctl              2.99573
# lresult_gt_lmedian                      1
# lresult_gt_lmean                        1
# lresult_lte_25pctl                      0
# lresult_gte_75pctl                      1
# labbatch                     SH-5/24/2000
# resultqualcode                          =
# qacode                                 NR
# sampleagency                       SDCDEH
# labagency                          SDCDEH
# submittingagency                   SDCDEH

# %%
# %mt_materialize stations '/Users/eric/Library/Application Support/metapack/_materialized_data/sandiegodata.org-beachwatch-1'

# %%
# %mt_materialize_all '/Users/eric/Library/Application Support/metapack/_materialized_data/sandiegodata.org-beachwatch-1'

# %%
# %mt_show_metatab

# %%
# %mt_show_libdirs
