# %%
import metapack as mp
# %matplotlib inline

# %%
pkg = mp.jupyter.open_package()
pkg
# Out:
# <h2>Tracts in San Diego County</h2>
# <p>census.gov-tracts-2017-sandiego-1</p>
#
# <p></p>
#
# <p>metapack+file:///Users/eric/proj/virt-proj/water/water-datasets/census.gov-tracts-sandiego/_packages/census.gov-tracts-2017-sandiego-1/metadata.csv</p>
#
# <h3>Contacts</h3>
# <p><strong>Wrangler:</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a> <a href="http://civicknowledge.com">Civic Knowledge</a></p>
# <h3>Resources</h3>
# <p><ol>
# <li><p><strong>tracts</strong> - <a target="_blank" href="file:///Users/eric/proj/virt-proj/water/water-datasets/census.gov-tracts-sandiego/_packages/census.gov-tracts-2017-sandiego-1/data/tracts.csv">file:///Users/eric/proj/virt-proj/water/water-datasets/census.gov-tracts-sandiego/_packages/census.gov-tracts-2017-sandiego-1/data/tracts.csv</a> </p></li>
# </ol></p>
# </ol>

# %%
r = pkg.resource('tracts')
r
# Out:
# <Resource: metadata.csv 26:1 root.datafile data/tracts.csv ['tracts', '', '']>

# %%
df = r.dataframe()

# %%
type(df)
# Out:
# metapack.jupyter.pandas.MetatabDataFrame

# %%
gdf = df.geo

# %%
# %matplotlib inline

# %%
gdf[(gdf.statefp == 6 ) & (gdf.countyfp == 73 )].plot()
